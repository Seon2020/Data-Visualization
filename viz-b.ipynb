# %% [markdown]
# # Data Visualization
# ## Top Spotify Songs From 2010-2019
# #### Sean Hawkins | 1/27/2021

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
top_spot_songs = pd.read_csv('top10s.csv')
top_spot_songs.head()
# Out:
#    position                 title      artist        top genre  year  bpm  \
# 0         1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1         2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2         3               TiK ToK       Kesha        dance pop  2010  120
# 3         4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4         5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
sns.relplot(x='year', y='pop', hue='dur', data=top_spot_songs)

# %% [markdown]
# - We can see that shorter songs tend to have a higher popularity over longer songs. In addition, we can see that an overwhelming majority of songs that even make this list are shorter songs.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x='year', y='pop', data=top_spot_songs, ci=None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='pop'>

# %% [markdown]
# - Please note that although this data is being provided by Spotify, it is based on Billboard. From the above barplot, we can clearly see that in recent years, songs that are successful on Billboard tend to have a higher popularity. I believe this is likely due to recent changes that Billboard has made to various chart algorithms. These changes reflect an important generational shift. We as a society have started to consume music differently (more streaming, less of actual purchasing). For example, Spotify and Apple Music streams are now weighed more heavily when it comes to how high a given song charts on Billboard.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.pointplot(x='year', y='val', data=top_spot_songs)
# Out:
# <AxesSubplot:xlabel='year', ylabel='val'>

# %% [markdown]
# - As we can see from the above pointplot, songs that have a higher valence (positive mood) were more popular in the early 2010's. Songs with a less positive mood have become increasing popular on Billboard in recent years.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.violinplot(x='year', y='nrgy', data=top_spot_songs)
# Out:
# <AxesSubplot:xlabel='year', ylabel='nrgy'>

# %% [markdown]
# In the above violinplot, you can see that the median energy level per year has been steadily decreasing since 2010. Songs that charted on Billboard in 2010 had the highest energy levels, and songs that charted on Billboard in 2018 had the lowest energy levels (when we are looking at the median).

# %% [markdown]
# ### Conclusions:
# - We can conclude that between 2010 and 2019, shorter songs had a tendency to be more popular over longer songs.
# - Songs that were successful on Billboard in the late 2010's generally had a higher popularity rating.
# - Songs that have a higher valence (positive mood) were more popular in the early 2010's than in the late 2010's.
# - The energy level of songs started to decrease as the 2010's progressed.
